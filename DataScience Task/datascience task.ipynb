# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#how to find missing values
#replace null values
#plot graph b/w 2 columns

# %%
df=pd.read_csv('exercise.csv')

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# 5            5   2  low fat     93  30 min     rest
# 6            6   3  low fat     97   1 min     rest
# 7            7   3  low fat     97  15 min     rest
# 8            8   3  low fat     94  30 min     rest
# 9            9   4  low fat     80   1 min     rest
# 10          10   4  low fat     82  15 min     rest
# 11          11   4  low fat     83  30 min     rest
# 12          12   5  low fat     91   1 min     rest
# 13          13   5  low fat     92  15 min     rest
# 14          14   5  low fat     91  30 min     rest
# 15          15   6   no fat     83   1 min     rest
# 16          16   6   no fat     83  15 min     rest
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# id            0
# diet          0
# pulse         0
# time          0
# kind          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# id            2
# diet          5
# pulse         2
# time          1
# kind          2
# dtype: int64

# %%
df.id.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89     True
# Name: id, Length: 90, dtype: bool

# %%
df[df.id.isnull()]
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 5            5 NaN  low fat    NaN  30 min     rest
# 89          89 NaN   no fat  150.0  30 min  running

# %%
df.iloc[5]
# Out:
# Unnamed: 0          5
# id                NaN
# diet          low fat
# pulse             NaN
# time           30 min
# kind             rest
# Name: 5, dtype: object

# %%
df.reset_index()
# Out:
#     index  Unnamed: 0    id     diet  pulse    time     kind
# 0       0           0   1.0  low fat   85.0   1 min     rest
# 1       1           1   1.0  low fat   85.0  15 min     rest
# 2       2           2   1.0  low fat   88.0  30 min     rest
# 3       3           3   2.0  low fat   90.0   1 min     rest
# 4       4           4   2.0  low fat   92.0  15 min     rest
# 5       5           5   NaN  low fat    NaN  30 min     rest
# 6       6           6   3.0  low fat   97.0   1 min     rest
# 7       7           7   3.0  low fat   97.0  15 min     rest
# 8       8           8   3.0  low fat   94.0  30 min     rest
# 9       9           9   4.0      NaN   80.0   1 min     rest
# 10     10          10   4.0  low fat   82.0  15 min     rest
# 11     11          11   4.0  low fat   83.0  30 min     rest
# 12     12          12   5.0      NaN   91.0   1 min     rest
# 13     13          13   5.0  low fat   92.0  15 min     rest
# ...

# %%
df.index.name="diet"

# %%
df
# Out:
#       Unnamed: 0    id     diet  pulse    time     kind
# diet
# 0              0   1.0  low fat   85.0   1 min     rest
# 1              1   1.0  low fat   85.0  15 min     rest
# 2              2   1.0  low fat   88.0  30 min     rest
# 3              3   2.0  low fat   90.0   1 min     rest
# 4              4   2.0  low fat   92.0  15 min     rest
# 5              5   NaN  low fat    NaN  30 min     rest
# 6              6   3.0  low fat   97.0   1 min     rest
# 7              7   3.0  low fat   97.0  15 min     rest
# 8              8   3.0  low fat   94.0  30 min     rest
# 9              9   4.0      NaN   80.0   1 min     rest
# 10            10   4.0  low fat   82.0  15 min     rest
# 11            11   4.0  low fat   83.0  30 min     rest
# 12            12   5.0      NaN   91.0   1 min     rest
# 13            13   5.0  low fat   92.0  15 min     rest
# 14            14   5.0  low fat   91.0  30 min     rest
# 15            15   6.0   no fat   83.0   1 min     rest
# ...

# %%
plt.plot(df['diet'].head(),df["pulse"].head())

# %%
df['id'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# Name: id, dtype: object

# %%
df[df.diet.isnull()]
# Out:
#     Unnamed: 0    id diet  pulse   time     kind
# 9            9   4.0  NaN   80.0  1 min     rest
# 12          12   5.0  NaN   91.0  1 min     rest
# 18          18   7.0  NaN   87.0  1 min     rest
# 51          51  18.0  NaN   92.0  1 min  walking
# 84          84  29.0  NaN   94.0  1 min  running

# %%
df[df.diet.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, diet, pulse, time, kind]
# Index: []

# %%
df
# Out:
#     Unnamed: 0    id     diet  pulse    time     kind
# 0            0   1.0  low fat   85.0   1 min     rest
# 1            1   1.0  low fat   85.0  15 min     rest
# 2            2   1.0  low fat   88.0  30 min     rest
# 3            3   2.0  low fat   90.0   1 min     rest
# 4            4   2.0  low fat   92.0  15 min     rest
# 5           32  32.0       32   32.0      32       32
# 6            6   3.0  low fat   97.0   1 min     rest
# 7            7   3.0  low fat   97.0  15 min     rest
# 8            8   3.0  low fat   94.0  30 min     rest
# 9            9   4.0      NaN   80.0   1 min     rest
# 10          10   4.0  low fat   82.0  15 min     rest
# 11          11   4.0  low fat   83.0  30 min     rest
# 12          12   5.0      NaN   91.0   1 min     rest
# 13          13   5.0  low fat   92.0  15 min     rest
# 14          14   5.0  low fat   91.0  30 min     rest
# 15          15   6.0   no fat   83.0   1 min     rest
# ...

# %%
df.iloc[5]
# Out:
# Unnamed: 0    1
# id            1
# diet          1
# pulse         1
# time          1
# kind          1
# Name: 5, dtype: object
